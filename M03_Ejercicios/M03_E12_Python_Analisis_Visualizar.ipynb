# %% [markdown]
# # M03_E12_DatosML_Python_Analizar_Visualizar
#
# ### PENSAMIENTO COMPUTACIONAL
#
# * Prof. Ricardo Vega M. - Escuela de Diseño Universidad Católica de Chile.
#
# * Renombrar archivo así: M03_E0X_apellido_nombre_rut, por ejemplo:
# M03_E0X_vega_ricardo_102349285
#
# * Renombrar el titulo asi: M0X_E0X_Nombre_EJercicio_apellido_nombre_rut, por ejemplo:
# M03_E0X_TIT_vega_ricardo_102349285
#
# * X equivale al número de la tarea.
#
# En la tarea de esta semana, veremos estas cosas:
#
# * 0- IMPORTAR LIBRERIAS
# * A- CARGAR DATOS.
# * B- EXPLORAR DATOS.
# * C- VISUALIZAR BARRAS.
# * D- VISUALIZAR SCATTERPLOT 1 y 4 CONJUNTOS:
# * E- VISUALIZAR SCATTERPLOT 4 CONJUNTOS EN UN PLOT:
# * F- VISUALIZAR WORDCLOUD WIKIPEDIA:
#
# Los datos a usar es el cuarteto de Anscombe. Esta es una base de datos muy simple con 4 conujuntos de datos, cada uno con su "X" e "Y" ( I_x, I_y; II_x, II_y; III_x, III_y; IV_x, IV_y). Es usada para ejemplificar la importancia de hacer visualizaciones para entender cómo se comportan los datos.
#
# Al obtener los resúmenes estadísticos de los 4 conjuntos de datos (mediana, moda, y desviación estandar) podemos ver que son iguales, pero la visualización nos demuestra que los datos se comportan de manera diferente.
#
# Para esto usaremos gráficos de barras, de puntos (scatterplot). Finalmente usaremos datos de wikipedia para una nube de palabras.
#
# Tarea:
# Para la tarea solo debe cargar los datos, colocar los valores correctos en los "?" (ubicarlos antes de ejecutar la celda), y hacer correr los códigos (secciones 0, A, B, C, D, y E). Y al final usar los códigos de ejemplo para crear su nube de palabras con los datos que le corresponden.

# %% [markdown]
# ## 0- IMPORTAR LIBRERIAS:

# %%
# 0- Importar librerias.
import pandas as pd # para trabajar con datos
import matplotlib.pyplot as plt # libreria visualización
import requests  # Para hacer solicitudes web
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## A- CARGAR DATOS:

# %%
## - - - - - - - - - - - -
## EN COLAB para cargar archivos
## - - - - - - - - - - - -

## Montar su Drive lara leer archivos.  
from google.colab import drive
drive.mount('/content/drive')

# %%
## Si trabaja desde colab: 
## Subir la carpeta e12_datos_vis_anscombe a su drive.
## Ir al ícono carpeta en la barra lateral
## Luego drive/MyDrive navegar y llegar a la carpeta donde tienen su material
## Algo así les va a aparecer: '/content/drive/MyDrive/su_ruta_a_la_carpeta/el_archivo.ogg'
## Ponerse sobre el archivo, ir a los tres puntitos, y copiar ruta de acceso
## Pegar la ruta en la variable correspondiente.

## Esta no le va a correr porque debe poner su ruta a los archivos.
ruta = '/content/drive/MyDrive/_2025B_UC/UC_DIS_PComp_2025B/10_PCOMP_Repo/colab_2024B_base/M03_Ejercicios/e12_datos_vis_anscombe/'

## aca nombre del archivo a traer
nombre_archivo = 'cuarteto_anscombe.csv'

# %%
## A.1- cargar datos, verificar separador inspeccionando el archivo
## Completar la ruta si lo importa desde colab. 

## Desde local: Descomentar esta linea si importa desde compu local. 
#ruta = 'e12_datos_vis_anscombe/'
#nombre_archivo = 'cuarteto_anscombe.csv'

df = pd.read_csv( ruta + nombre_archivo , sep=',') 

# mostramos 
print("forma:", df.shape) # cuantas filas y columnas
df
# Out:
# forma: (11, 8)
#      I_x    I_y  II_x  II_y  III_x  III_y  IV_x   IV_y
# 0   10.0   8.04  10.0  9.14   10.0   7.46   8.0   6.58
# 1    8.0   6.95   8.0  8.14    8.0   6.77   8.0   5.76
# 2   13.0   7.58  13.0  8.74   13.0  12.74   8.0   7.71
# 3    9.0   8.81   9.0  8.77    9.0   7.11   8.0   8.84
# 4   11.0   8.33  11.0  9.26   11.0   7.81   8.0   8.47
# 5   14.0   9.96  14.0  8.10   14.0   8.84   8.0   7.04
# 6    6.0   7.24   6.0  6.13    6.0   6.08   8.0   5.25
# 7    4.0   4.26   4.0  3.10    4.0   5.39  19.0  12.50
# 8   12.0  10.84  12.0  9.13   12.0   8.15   8.0   5.56
# 9    7.0   4.82   7.0  7.26    7.0   6.42   8.0   7.91
# 10   5.0   5.68   5.0  4.74    5.0   5.73   8.0   6.89

# %%
## A1- Cargar datos. pd.read_csv para leer archivos .csv (hay comandos para leer json, excel, entre otros)
## DESDE COMPU LOCAL USAR ESTE CÓDIGO PARA TRAER ARCHIVOS

ruta_archivo = 'e12_datos_vis_anscombe/cuarteto_anscombe.csv'
df = pd.read_csv( ruta_archivo ) # ruta archivo solo si estan en compu local

# mostrar el dataframe donde se guardaron los datos
df
# Out:
#      I_x    I_y  II_x  II_y  III_x  III_y  IV_x   IV_y
# 0   10.0   8.04  10.0  9.14   10.0   7.46   8.0   6.58
# 1    8.0   6.95   8.0  8.14    8.0   6.77   8.0   5.76
# 2   13.0   7.58  13.0  8.74   13.0  12.74   8.0   7.71
# 3    9.0   8.81   9.0  8.77    9.0   7.11   8.0   8.84
# 4   11.0   8.33  11.0  9.26   11.0   7.81   8.0   8.47
# 5   14.0   9.96  14.0  8.10   14.0   8.84   8.0   7.04
# 6    6.0   7.24   6.0  6.13    6.0   6.08   8.0   5.25
# 7    4.0   4.26   4.0  3.10    4.0   5.39  19.0  12.50
# 8   12.0  10.84  12.0  9.13   12.0   8.15   8.0   5.56
# 9    7.0   4.82   7.0  7.26    7.0   6.42   8.0   7.91
# 10   5.0   5.68   5.0  4.74    5.0   5.73   8.0   6.89

# %% [markdown]
# ## B- EXPLORAR DATOS:
#
# La exploracin permite reconocer la forma y características principales y de los datos (cuantos, de qué tipo). Para una primera exploración se usan estas 4 funciones de Pandas:
#
# * df.shape: permite ver cuantas filas y columnas tiene nuestro archivo.
# * df.info(): muestra nombres de columnas, cuantos son nulos o vacíos. Es importante ver tipo de datos, para saber que columnas son string (object), números, etc.
# * df.describe(): muestra las principales descripciones estadísticas, solo de las columnas numéricas.
# * df.columns: para obtener los nombres de las columnas.

# %%
## B1- Shape devuelve una tupla (un conjunto de valores (a, b) ) 
df.shape

#type(df.shape) # descomentar para ver tipo de dato
# Out:
# (11, 8)

# %%
## B2- info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   I_x     11 non-null     float64
#  1   I_y     11 non-null     float64
#  2   II_x    11 non-null     float64
#  3   II_y    11 non-null     float64
#  4   III_x   11 non-null     float64
#  5   III_y   11 non-null     float64
#  6   IV_x    11 non-null     float64
#  7   IV_y    11 non-null     float64
# dtypes: float64(8)
# memory usage: 832.0 bytes

# %%
## B3- describe
df.describe()
# Out:
#              I_x        I_y       II_x       II_y      III_x      III_y  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#             IV_x       IV_y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
## B4- Nombres columnas
df.columns
# Out:
# Index(['I_x', 'I_y', 'II_x', 'II_y', 'III_x', 'III_y', 'IV_x', 'IV_y'], dtype='object')

# %%
## B5- Reportar en un print cuantas columnas, filas tiene
## debe guardar el shape en una variable e incoroprarla en el print

columnas = df.shape[0]
filas    = df.shape[1]

## Mostrar
frase = "Los datos tienen {} filas y {} columnas".format(columnas, filas)
print( frase ) # aca mostrar la frase
# Out:
# Los datos tienen 11 filas y 8 columnas

# %% [markdown]
# ## C- VISUALIZAR BARRAS:
#
# Con los datos del ejemplo, haremos un gráfico de barras simple para mostrar algunos datos.

# %%
## C1- Puede ver los nombres de las variables del df con columns
df.columns
# Out:
# Index(['I_x', 'I_y', 'II_x', 'II_y', 'III_x', 'III_y', 'IV_x', 'IV_y'], dtype='object')

# %%
## C1- Guardamos las columnas en unas variables para que sea más fácil.
## de las columnas seleccionar el x e y de un conjunto o set de datos

set1_x = df['I_x']
set1_y = df['I_y']
bar_titulo = "ANSCOMBE"

## Hacer el gráfico
plt.figure( figsize=(14,4) ) # ancho x alto
plt.title( bar_titulo )
plt.bar(x=set1_x, height = set1_y )
plt.show()


## Guarda el gráfico en la ruta seleccionada.
#plt.savefig('e11_datos/ciej_utiles_limpio_barra1.jpg') #descomentar para guardar local


## Si esta en colab puede usar algo como esto. Descomentar para usar
#from google.colab import files
#plt.savefig("migrafico1.png")
#files.download("migrafico1.png")

# %% [markdown]
# ## D- VISUALIZAR SCATTERPLOT 1 y 4 CONJUNTOS:
#
# Un gráfica de dispersión (burbujas, bolas, etc) es un tipo de diagrama con coordenadas cartesianas, y permite mostrar dos variables de un conjunto de datos. En este scaterpot graficaremos los 4 conjuntos o set de datos, I, II, III y IV.

# %%
## D1- Primero como ejemplo haremos un scatterplot de un solo conjunto de datos.

## Datos seleccionados del conjunto I
x1 = df['I_x']
y1 = df['I_y']

## Tamaño y proporción del gráfico.
fig = plt.figure(figsize=(6, 4))

plt.title("Cuarteto de Anscombe x1 e x1 x de serie I") # título.
plt.xlabel("El Eje X") # texto eje X.
plt.ylabel("El Eje Y") # texto eje Y.

plt.scatter(x=x1, y=y1, color='red') # gráfico de puntos.
plt.show()

# %%
## D2- En este scaterpot graficaremos los 4 conjuntos (sets) de datos, I, II, III y IV.
## Seleccionar los datos, colcarlos en el gráfico correspondiente, poner títulos, y seleccionar diferentes colores.

x1, y1 = df['I_x'], df['I_y']
x2, y2 = df['II_x'], df['II_y']
x3, y3 = df['III_x'], df['III_y']
x4, y4 = df['IV_x'], df[ 'IV_y' ]

## Tamaño y proporción del gráfico.
fig=plt.figure(figsize=(16, 10)) # tamaño del gráfico.

## grafica el primer conjunto. 
plt.subplot(221) # 2 columnas, 2 filas y posición 1.
plt.title('Serie I')
plt.scatter(x1, y1, s=80, color='red', marker='o' )

## grafica el segundo conjunto. 
plt.subplot(222) # 2 columnas, 2 filas y posición 2.
plt.title('Serie II')
plt.scatter(x2, y2, s=80, color='blue', marker='o')

## grafica el tercer conjunto. 
plt.subplot(223)
plt.title('Serie III') # 2 columnas, 2 filas y posición 3.
plt.scatter(x3, y3, s=80, color='orange', marker='o')

## grafica el cuarto conjunto. 
plt.subplot(224) # 2 columnas, 2 filas posición 4.
plt.title('Serie IV')
plt.scatter( x4, x4 , s=80, color='green', marker='o')

plt.show()

# %%
## D3- Describir resumen estadístico.
## Atención a los graficos:
## Lo resúmenes estadísticos dicen que todos los datos son iguales
## Pero los gráficos muestran otra cosa...

df.describe() # fiajarse en ""mean", "std" de los x y los y, varios son iguales
# Out:
#              I_x        I_y       II_x       II_y      III_x      III_y  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#             IV_x       IV_y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %% [markdown]
# ### Comparación estadísticos (describe) y gráficos
#
# Observe y compare el promedio (mean), la desviación estandar (std) de los 4 conjuntos. los x son iguales, los y son iguales.
#
# Según estas estadísticas, se podria decir que los 4 se comportan igual. Pero los gráficos muestran distribuciones diferentes. La importancia de la visualización radica en que muestra patrones de comportamiento de los datos, lo que permite detectar como se distribuyen, como se agrupan, y si existen outliers (datos que se escapan de los grupos)

# %% [markdown]
# ## E- VISUALIZAR SCATTERPLOT 4 CONJUNTOS EN UN PLOT:
#
# En este scaterpot graficaremos dos conjuntos de datos, I y II.
# como ejercicio puede incorporar las  series III y IV y adaptar colores y titulos.

# %%
## E1- Scatterplot oi grafico de puntos (pueden tener otras formas tb)

## Datos - - - - - - - - - - - -
## guardamos datos en variables
g1 = (df['I_x'], df['I_y'])
g2 = (df['II_x'], df['II_y'])
g3 = (df['III_x'], df['III_y'])
g4 = (df['IV_x'], df['IV_y'])

gdatos   = (g1, g2, g3, g4 ) # guardamos esos grupos en la variable gdatos para acceder facilmente.
gnombres = ('El grupo 1', 'El grupo 2', 'El grupo 3', 'El grupo 4') # guardamos nombres de grupos
gcolores = ('red', 'blue', 'green', 'orange') # guardamos colores, puede cambiarlos: otors colores: https://matplotlib.org/stable/gallery/color/named_colors.html
gmarker  = ('o', 'v', 'd', 's'  ) # markers o formas de puntos, aca mas: https://matplotlib.org/stable/api/markers_api.html


## Crear gráficos - - - - - - - - - - - -
fig=plt.figure(figsize=(10, 6), facecolor='lightslategray') # tamaño del gráfico.
fig.patch.set_facecolor('green') # color del margen.
fig.patch.set_alpha(0.2) # transparencia del margen.

ax = fig.add_subplot(1, 1, 1) # agregar sub gráficos en el mismo espacio.
ax.patch.set_color('yellow') # color del gráfico.
ax.patch.set_alpha(0.9) # transparencia del gráfico.

plt.title("El Famoso Cuarteto de Anscombe") # titulo general.
plt.xlabel("Este es el Eje X") # texto eje X.
plt.ylabel("Este es el Eje Y") # texto eje Y.
plt.grid( color='grey', alpha=0.5) # grilla.

## se recorre la info de gdatos, gcolores, gnombres y se guardan en dat, col, gru.
for dat, col, gru, mar in zip(gdatos, gcolores, gnombres, gmarker):
    x, y = dat
    ax.scatter(x, y, alpha=0.6, c=col, edgecolors='none', s=80, label=gru, marker=mar) # puntos.
    plt.legend(gnombres) # leyendas.


## Mostrar grafico 
## SOLO COMPU LOCAL guarda el grafico en la ruta seleccionada.
#plt.savefig('a_cuarteto_scatter_series.jpg') # le piuede aparecer en la columna de al lado en los archivos

## DESCOMENTAR SOLO EN COLAB
#files.download("a_cuarteto_scatter_series.jpg")

## esta linea muestra el grafico.
plt.show()

# %% [markdown]
# ## F- VISUALIZAR WORDCLOUD WIKIPEDIA:
#
# Se puede visualizar texto con  texto de wikipedia u otro. En este ejemplolo realizaremoc con un articulo de wikipedia

# %%
## Traer esta librería porque no esta instalada por defecto en colab.
## más info https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Wikipedia_API_for_Python.ipynb#scrollTo=GciTaTsc2Kk_

# !pip install wikipedia # Para usar articulo de wikipedia

# %%
## Importar librerías
import wikipedia # Para usar articulo de wikipedia
import requests  # Para hacer solicitudes web.
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator # Para generar WORD CLOUD con textos

# %%
## F.1- Seleccionar articulo wikipedia

## Selecciona el idioma del artículo de WP.
wikipedia.set_lang("es")

## Ejemplo
## cual articulo a escoger: Visitar esta URL de ejemplo: https://es.wikipedia.org/wiki/La_Araucana
ejemplo_articulo_wp = 'La_Araucana'
articulo = wikipedia.page( ejemplo_articulo_wp )

## De las siguientes descomentar la que desee ver.

#print(articulo.original_title) # titulo del articulo
print( articulo.summary ) # sumario del articulo
print(articulo.content) # contenido textual del articulo
#print( articulo.categories ) # categorias del articulo
#print( articulo.images ) # lista url de imagenes del articulo
#print( articulo.url ) # url del articulo
#print(articulo.links[:]) # links que aparecen en el articulo
#print(articulo.html) # muestra html del articulo
# Out:
# La Araucana (1569, 1578 y 1589) es un poema épico del español Alonso de Ercilla que relata la primera fase de la conquista de Chile, particularmente la Guerra de Arauco que enfrentó a españoles y mapuches, pueblo referido bajo el exónimo de «araucanos» en el texto, término de uso frecuente en la época de composición del poema.​
# La Araucana (1569, 1578 y 1589) es un poema épico del español Alonso de Ercilla que relata la primera fase de la conquista de Chile, particularmente la Guerra de Arauco que enfrentó a españoles y mapuches, pueblo referido bajo el exónimo de «araucanos» en el texto, término de uso frecuente en la época de composición del poema.​
#
#
# == Historia: Contexto de la obra y ésta como fuente ==
#
#
# === Escritura y publicación ===
# ...

# %%
## F2- Crear y generar una nube de palabras.
## buen tutorial: https://www.datacamp.com/tutorial/wordcloud-python?utm_source=google&utm_medium=paid_search&utm_campaignid=21057859163&utm_adgroupid=157296744657&utm_device=c&utm_keyword=&utm_matchtype=&utm_network=g&utm_adpostion=&utm_creative=692112538450&utm_targetid=aud-2274077226600:dsa-2218886984100&utm_loc_interest_ms=&utm_loc_physical_ms=9198028&utm_content=&utm_campaign=230119_1-sea~dsa~tofu_2-b2c_3-es-lang-en_4-prc_5-na_6-na_7-le_8-pdsh-go_9-nb-e_10-na_11-na-fawnov24&gad_source=1&gclid=Cj0KCQiA0MG5BhD1ARIsAEcZtwS5pg-UuwoLtroXBS3Amgjby3Pz5Qa2Hw7SvBbgZ9jzf-x4j4QMwSAaAuN0EALw_wcB

## cual articulo usaremos para la nube de palabas, el seleccionado mas arriba
cual_texto = articulo.content

## StopWords son palabras que no quiero que aparezcan
## Completar la lista con las que estime (ojo con las comas y las comas)
mis_stopw = ['a','al','de','del','e','el','en','esto','es','entre','la','las','le','más','por','se','sin embargo','Sin embargo','su','sus','que','un','una','o','y' ]

## Genera la nube de palabras, pero falta mostrarla mas abajo
wordcloud = WordCloud( width=1000, height=500, min_font_size=10, max_font_size=150, max_words=50,
                      background_color="white", stopwords=mis_stopw ).generate( cual_texto )

## Mostrar wordcloud
plt.figure(figsize=(14, 10) )
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# se guardará en lal caepeta de al aldo
# desde allí se puede descargar.
#wordcloud.to_file("e12_wordcloud.png")

# %% [markdown]
# ## – – – – – – – – – – – – – – – – – – – – – – – – – – – – – – – – – –
# ## AHORA USTED
# ## – – – – – – – – – – – – – – – – – – – – – – – – – – – – – – – – – –
#
# Hacer una nue de palabras con solamente los pasos F1 y F2 COPIANDO los códigos y seleccionando el artículo que corresponde según su rut.
#
# * c0_wiki = 'Algoritmo de la colonia de hormigas'
# * c1_wiki = 'Synco'
# * c2_wiki = 'Cuarteto_de_Anscombe'
# * c3_wiki = 'Python'
# * c4_wiki = 'Protobionte'
# * c5_wiki = 'Richard_Stallman'
# * c6_wiki = 'Linus_Torvalds'
# * c7_wiki = 'IRT_(electrodomésticos)'
# * c8_wiki = 'Antu_(televisor)'
# * c9_wiki = 'Fortran'
# * ck_wiki = 'Autopoiesis'

# %% [markdown]
# ## F1- VISUALIZAR WORDCLOUD WIKIPEDIA (3 puntos):

# %%
## Copiar F1 acá, y modificar el articulo a escoger.

# %% [markdown]
# ## F2- VISUALIZAR WORDCLOUD WIKIPEDIA (3 puntos):

# %%
## Copiar F2 acá y modificar el cual texto mostrar

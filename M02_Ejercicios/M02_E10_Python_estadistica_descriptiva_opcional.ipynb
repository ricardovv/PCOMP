# %% [markdown]
# # M02_E10_Python_Estadistica_Descriptiva
#
# ### PENSAMIENTO COMPUTACIONAL
#
# * Prof. Ricardo Vega M. - Escuela de Diseño Universidad Católica de Chile.
#
# * Renombrar archivo así: M0X_E0X_apellido_nombre_rut, por ejemplo:
# M0X_E0X_vega_ricardo_102349285
#
# * Renombrar el titulo asi: M0X_E0X_PRINT_SUMAR_apellido_nombre_rut, por ejemplo:
# M02_E10_Python_Estadística_Descriptiva_vega_ricardo_102349285
#
# * X equivale al número de la tarea.
#
# En esta tarea, veremos alspectos básicos de Estadística descriptiva, como para recordar la Media ;). No son los únicos métodos, son los más simples y básicos:
#
# 0- Importar librerias.
# A- Cargar Datos y Exploracion inicial.
# B- Medidas de tendencia central o posición.
# C- Medidas de dispersión, variación o variabilidad.
# D- Graficando algunas variables: Barras.
# E- Graficando algunas variables: Scatterplot y Torta.

# %% [markdown]
# ## QUÉ ES ESTADÍSTICA?
#
# **Estadística:** Describe un conjunto de datos obtenidos para tomar decisiones o realizar generalizaciones sobre características de las observacione. Usa un conjunto de métodos para obtener, analizar y presentar observaciones numéricas y/(o no numéricas.
#
# **Dos ramas en Estadística:** La estadística se divide en dos grandes áreas, una describe lo dado, la otra busca predecir la ocurrencia de un fenómeno.
#
# **A) Estadística descriptiva:** Resume datos de fenómenos usando métodos de recolección, descripción, visualización. Los datos pueden ser resumidos numérica o gráficamente. Usa medidas de descripción numérica como la media y la desviación estandar.
#
# **B) Estadística Inferencial:** Busca generalizar modelos, realizar inferencias y predicciones de fenómenos considerando la incertidumbre en las observaciones (probabilidad). Las inferencias pueden ser: estimaciones de características numéricas (estimación), pronósticos de futuras observaciones, descripciones de asociación (correlación), o relaciones entre variables (regresión), entre otras.
#
# **Erorres más fecruentes en Estadística:** Datos de muestras no son representativos. Las conclusiones erróneas por datos insuficientes. Las representaciones gráficas pueden ser engañosas o distorsionadas (escalas). Ciertas categorías incorrectas. Respuestas o datos sesgadas.
#
# ## TIPOS DE DATOS
# Según su naturaleza, los datos pueden ser:
#
# **Cualitativos:** Valores de cualidades o atributos, clasificados en categorías. No son numéricos. Ej:
# * Sexo: f/m.
# * Hábito de fumar: Fumador/No fumador
# * Estado civil: soltero, casado, divorciado, ...
#
# **Cuantitativos:** Valores que pueden cuantificarse o expresarse numéricamente. Ej:
# *  Peso, Edad, Estatura: 1,60, 1,70, 180, ...
# *  Presión, Humedad, Temperatura: 20, 30, 18, ...
# *  Notas de un examen: 4.0, 5.5, 6.8, ...
#
# **Datos discretos:** Datos que no pasan de una clase a la siguiente sin que haya una interrupción, representadas como números enteros. Ej:
# * Estudiantes de PhD en una universidad.
# * 2 gatos
# * 2 líneas de metro
#
# **Datos continuos:** Datos que pueden pasar de una clase otra siguiente sin interrupción y que pueden expresarse mediante números enteros o fraccionarios. Puede tomar cualquier valor en una escala continua. Ej:
# * Cantidad de líquido: 800, 800.5, ...
# * Peso: 60.25, 70.2, ...
#
# **Univariadas o unidimensional:** Recogen información sobre una característica. Ej:
# * edad de alumnos.
# * autos vendidos.
#
# **Bivariado o bidimensional:** Recogen información sobre dos características de la población. Ej:
# * edad y estatura de alumnos.
# * autos vendidos y su marca.
#
# **Multivariados o pluridimensional:** recogen información sobre tres ó más características. Ej:
# * edad, estatura, y peso de alumnos.
# * autos vendidos, su marca, y año.

# %% [markdown]
# ## 0- Importar librerías, cargar y explorar datos

# %%
## importar librería Pandas.
import pandas as pd

# importar librería visualización.
import matplotlib.pyplot as plt

# %% [markdown]
# ## A- Cargar Datos y Exploración inicial.
#
# Usaremos el archivo worldcup2014.csv con datos sobre la copa del mundo del 2014.
# Recordar que debe subir la carpeta datos_e10 a su drive.

# %%
## Recordar que para cargar datos desde Google drive:

## Usar este código para acceder a su Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Subir la carpeta datos_e10 a su drive.
## Ir al ícono carpeta en la barra lateral
## Luego drive/MyDrive navegar y llegar a la carpeta donde tienen su material
## Algo así les va a aparecer: '/content/drive/MyDrive/su_ruta_a_la_carpeta/el_archivo.ogg'
## Ponerse sobre el archivo, ir a los tres puntitos, y copiar ruta de acceso
## Pegar la ruta en la variable correspondiente.

## Esta no le va a correr porque debe poner su ruta a los archivos.
ruta_archivo = '/content/drive/MyDrive/_2025B_UC/UC_DIS_PComp_2025B/10_PCOMP_Repo/colab_2024B_base/M02_Ejercicios/datos_e10/worldcup2014.csv'


## cargar datos: pd.read_csv para leer archivos .csv
df = pd.read_csv(ruta_archivo, sep=',') # ojo con el separador

## Mostrar datos
df
# Out:
#                       team     continent group  group_pos  cantidad_juegos  \
# 0                   Brazil  southamerica     A          1                3
# 1                   Mexico  northamerica     A          2                3
# 2                  Croatia        europe     A          3                3
# 3                 Cameroon        africa     A          4                3
# 4              Netherlands        europe     B          1                3
# 5                    Chile  southamerica     B          2                3
# 6                    Spain        europe     B          3                3
# 7                Australia          asia     B          4                3
# 8                 Colombia  southamerica     C          1                3
# 9                   Greece        europe     C          2                3
# 10             Ivory Coast        africa     C          3                3
# ...

# %%
## muestra la forma general del dataframe: cantidad de filas y columnas.
df.shape
# Out:
# (32, 13)

# %%
## Mostrar las primeras 5 filas.
df.head()
#df.head(2) # si lo prefiere puede mostrar algunas filas
# Out:
#           team     continent group  group_pos  cantidad_juegos  \
# 0       Brazil  southamerica     A          1                3
# 1       Mexico  northamerica     A          2                3
# 2      Croatia        europe     A          3                3
# 3     Cameroon        africa     A          4                3
# 4  Netherlands        europe     B          1                3
#
#    juegos_ganados  juegos_empatados  juegos_perdidos  goles_favor  \
# 0               2                 1                0            7
# 1               2                 1                0            4
# 2               1                 0                2            6
# 3               0                 0                3            1
# 4               3                 0                0           10
#
#    goles_contra goles_diferencia  puntos  clasificado
# 0             2                5       7            1
# 1             1                3       7            1
# ...

# %%
## Mostrar últimas 5 filas.
df.tail()
#df.tail(2) # si lo prefiere puede mostrar algunas filas
# Out:
#            team continent group  group_pos  cantidad_juegos  juegos_ganados  \
# 27        Ghana    africa     G          4                3               0
# 28      Belgium    europe     H          1                3               3
# 29      Algeria    africa     H          2                3               1
# 30       Russia    europe     H          3                3               0
# 31  South Korea      asia     H          4                3               0
#
#     juegos_empatados  juegos_perdidos  goles_favor  goles_contra  \
# 27                 1                2            4             6
# 28                 0                0            4             1
# 29                 1                1            6             5
# 30                 2                1            2             3
# 31                 1                2            3             6
#
#    goles_diferencia  puntos  clasificado
# 27               −2       1            0
# ...

# %%
## Resúmen estadístico de las columnas: promedio, desviación estandar, valores mínimos y máximos.
## Solo considera las columnas que tienen valores numéricos.
df.describe()
# Out:
#        group_pos  cantidad_juegos  juegos_ganados  juegos_empatados  \
# count  32.000000             32.0       32.000000         32.000000
# mean    2.500000              3.0        1.218750          0.562500
# std     1.135924              0.0        1.007532          0.564401
# min     1.000000              3.0        0.000000          0.000000
# 25%     1.750000              3.0        0.000000          0.000000
# 50%     2.500000              3.0        1.000000          1.000000
# 75%     3.250000              3.0        2.000000          1.000000
# max     4.000000              3.0        3.000000          2.000000
#
#        juegos_perdidos  goles_favor  goles_contra     puntos  clasificado
# count         32.00000    32.000000     32.000000  32.000000    32.000000
# mean           1.21875     4.250000      4.250000   4.218750     0.500000
# std            0.97499     2.314052      2.228843   2.881917     0.508001
# ...

# %%
## Información general de los datos: tipo de datos, filas, columnas...
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   team              32 non-null     object
#  1   continent         32 non-null     object
#  2   group             32 non-null     object
#  3   group_pos         32 non-null     int64
#  4   cantidad_juegos   32 non-null     int64
#  5   juegos_ganados    32 non-null     int64
#  6   juegos_empatados  32 non-null     int64
#  7   juegos_perdidos   32 non-null     int64
#  8   goles_favor       32 non-null     int64
#  9   goles_contra      32 non-null     int64
#  10  goles_diferencia  32 non-null     object
#  11  puntos            32 non-null     int64
#  12  clasificado       32 non-null     int64
# dtypes: int64(9), object(4)
# memory usage: 3.4+ KB

# %%
## Nombres de columnas del dataframe.
cols = df.columns
cols
# Out:
# Index(['team', 'continent', 'group', 'group_pos', 'cantidad_juegos',
#        'juegos_ganados', 'juegos_empatados', 'juegos_perdidos', 'goles_favor',
#        'goles_contra', 'goles_diferencia', 'puntos', 'clasificado'],
#       dtype='object')

# %%
## Selecciona una columna y muestra sus valores.
df['continent']
# Out:
# 0     southamerica
# 1     northamerica
# 2           europe
# 3           africa
# 4           europe
# 5     southamerica
# 6           europe
# 7             asia
# 8     southamerica
# 9           europe
# 10          africa
# 11            asia
# 12    northamerica
# 13    southamerica
# 14          europe
# 15          europe
# 16          europe
# 17          europe
# 18    southamerica
# 19    northamerica
# 20    southamerica
# 21          africa
# 22          europe
# 23            asia
# 24          europe
# 25    northamerica
# 26          europe
# 27          africa
# 28          europe
# 29          africa
# 30          europe
# 31            asia
# Name: continent, dtype: object

# %%
## Selecciona una columna y agrupa por continente.
df['continent'].value_counts()
# Out:
# continent
# europe          13
# southamerica     6
# africa           5
# northamerica     4
# asia             4
# Name: count, dtype: int64

# %% [markdown]
# ## B- Medidas de tendencia central o posición.
#
# Son valores que generalmente se ubican en la parte central de un conjunto de datos. Indican como los datos se condensan en un solo valor central, alrededor del cual los demás datos se distribuyen. Son la Media aritmética, Mediana, y la Moda.
#
# **Media Aritmética:** Es la suma de todas las observaciones dividida entre el total de observaciones. es una de las formas más usadas para resumir la información de una distribución, pero es a veces engañosa, ¿Por qué?
#
# Ventajas: Es un concepto familiar para la mayoría de las personas. Permite la comparación de medias de varios conjuntos de datos.
#
# Desventajas: Se ve afectada por valores extremos, perdiendo representatividad. No se puede calcular para datos cualitativos. "Si mi vecino tiene dos coches y yo ninguno, los dos tenemos uno”.
#
# 1, 3, 6, 2, 4, 2, 5
# Total= 23
# 23/7 = 3.28
#
#
# **Mediana:** Valor que ocupa la posición central de un conjunto de datos, una vez ordenados en forma ascendente o descendente. Divide al conjunto de datos en dos partes iguales, par o impar.
#
# Ventajas: Fácil de calcular. No se ve influida por valores extremos, solo influyen valores centrales. Fácil de entender.
#
# Desventajas: No utiliza en su “cálculo” toda la información disponible. No pondera cada valor por el número de veces que se ha repetido. Hay que ordenar los datos antes de determinarla.
#
# 1, 3, 6, 2, 4, 2, 5
# 1, 2, 2 (3) 4, 5, 6 - ordenados
#
#
# **Moda:** Observación que tiene la mayor frecuencia en un conjunto de datos. Un conjunto de datos puede ser unimodal, bimodal o multimodal.
#
# Ventajas: Fácil de interpretar. No requiere cálculos solo contar las que más se repiten. Puede usarse para datos cuantitativos y cualitativos. No se ve influida por valores extremos.
#
# Desventajas: Tiene significado en el caso de una gran cantidad de datos. No utiliza toda la información disponible. No siempre existe, si los datos no se repiten. El azar puede hacer que una observación no representativa sea el valor más frecuente. Difícil de interpretar si los datos tienen 3 o más modas.
#
# 1, 3, 6, 2, 4, 2, 5
# 2 (se repite 2 veces)

# %%
## un dato en goles_diferencia esta con problemas, hay que pasarlo a int (numeros enteros)
df['goles_diferencia'] = pd.to_numeric(df['goles_diferencia'], downcast='integer', errors='coerce')

# %% [markdown]
# ### ¿Qué podemos decir de los datos hasta ahora? O mejor Dicho, ¿Qué tipo de preguntas podemos hacernos sobre los datos?
# * ¿Son muchos o pocos datos?
# * ¿Hay grupos dentro de estos?
# * ¿Cuál es el más goleador, o el que ha ganado más partidos?
# * ¿Qué equipo ha tenido el peor desempeño?
# * ¿Qué continente ha tenido el mejor desempeño?

# %%
## Media aritmética.
## Veamos el promedio de los juegos ganados. Luego puede probar con otra columna numérica.
promedio = df['juegos_ganados'].mean()
print("-Promedio:", promedio )

## Podemos total juegos ganados por continente
ganados = df.groupby('continent').juegos_ganados.sum()
print("-Ganados:", ganados )

## Promedio total juegos ganados por continente
ganados_promedio = df.groupby('continent').juegos_ganados.mean()
print("-Ganados Promedio:", ganados_promedio )
# Out:
# -Promedio: 1.21875
# -Ganados: continent
# africa           3
# asia             0
# europe          18
# northamerica     5
# southamerica    13
# Name: juegos_ganados, dtype: int64
# -Panados Promedio: continent
# africa          0.600000
# asia            0.000000
# europe          1.384615
# northamerica    1.250000
# southamerica    2.166667
# Name: juegos_ganados, dtype: float64

# %%
## Mediana.
mediana = df['juegos_ganados'].median()
mediana
# Out:
# 1.0

# %%
## Moda.
moda = df['juegos_ganados'].mode(dropna=True)
moda
# Out:
# 0    1
# Name: juegos_ganados, dtype: int64

# %% [markdown]
# ## C- Medidas de dispersión, variación o variabilidad.
#
# * Son valores numéricos que indican o describen la forma en que las observaciones están dispersas respecto al valor central.
# * Son importantes debido a que dos muestras de observaciones con el mismo valor central pueden tener una variabilidad muy distinta.
# * Son: Rango, Varianza (no la veremos). Desviación Estándar.
#
# #### Rango:
# * Es la diferencia entre el dato mayor y el menor.
# * Permite conocer la máxima dispersión.
# * Se emplea poco debido a que depende únicamente de dos valores.
# * Desventajas:
#     * No es una medida de Dispersión con respecto al centro de la distribución.
#     * Solo emplea dos valores en su cálculo.
#
# 1, 3, 6, 2, 4, 2, 5
# mayor = 6
# menor = 1
# rango (mayor - menor) = 5
#
#
#
# #### Desviación Estandar:
# * Es la raíz cuadrada de la varianza.
# * Permite ver que tan lejos está un valor del centro.
# Ventajas:
# * Expresada en las mismas unidades que la variable en estudio.
# * Utiliza todas las observaciones en su cálculo.
# * Fácil de interpretar.
# Desventajas:
# * No tiene.
#
# 1, 3, 6, 2, 4, 2, 5
# media 3.28
# 1 esta a 2.28 std
# 6 esta a 2.71 std

# %%
## Maximo
max = df['juegos_ganados'].max(numeric_only=True)
print("Valor Máximo: ", max )

## Minimo
min = df['juegos_ganados'].min(numeric_only=True)
print("Valor Mínimo: ", min )
# Out:
# Valor Máximo:  3
# Valor Mínimo:  0

# %%
## Rango de variable juegos ganados.
rango = df['juegos_ganados'].max() - df['juegos_ganados'].min()
print( "Rango:", rango )
# Out:
# Rango: 3

# %%
## Desviacion Estandar

desv_est = df['juegos_ganados'].std()
print( "desviacion_estandar:", desv_est )
# Out:
# desviacion_estandar: 1.0075321174741456

# %% [markdown]
# * Puede probar sacando las descriptivas para cada columna
#     * cantidad_juegos
#     * juegos_ganados
#     * juegos_empatados
#     * juegos_perdidos
#     * goles_favor
#     * goles_contra
#     * goles_diferencia
#     * puntos

# %% [markdown]
# ## D- Graficando algunas variables: Barras.
#
# Para trabajar con gráficos y crear visualizaciones, existen muchas librerías para Python, las más conocidas:
#
# **Matplotlib:** una de las más usadas, simple y completa, muchas otras se basan en esta. https://matplotlib.org/
#
# **Seaborn:** basada en MAtplotlib, con mejoras que la hacen más simple.  https://seaborn.pydata.org/
#
# **Bokeh:** posee elementos de interacción y es posible de ser usada en la web. https://bokeh.org/
#
# **Geoplotlib:** Principalmente orientada a mapas y sistemas de información geográfica.  https://github.com/andrea-cuttone/geoplotlib
#
# Puede ver más referencias sobre creación de gráficos con matplotlib en: https://www.tutorialspoint.com/matplotlib/index.htm

# %%
## se recomienda nuevamente inspeccionar los datos  rapidamente
df.head()
# Out:
#           team     continent group  group_pos  cantidad_juegos  \
# 0       Brazil  southamerica     A          1                3
# 1       Mexico  northamerica     A          2                3
# 2      Croatia        europe     A          3                3
# 3     Cameroon        africa     A          4                3
# 4  Netherlands        europe     B          1                3
#
#    juegos_ganados  juegos_empatados  juegos_perdidos  goles_favor  \
# 0               2                 1                0            7
# 1               2                 1                0            4
# 2               1                 0                2            6
# 3               0                 0                3            1
# 4               3                 0                0           10
#
#    goles_contra  goles_diferencia  puntos  clasificado
# 0             2               5.0       7            1
# 1             1               3.0       7            1
# ...

# %%
## Gráfico de barras de una columna.

x1 = df['team'] # en x1 la variable independiente
y1 = df['goles_favor'] # en y1 guardaremos la variable dependiente

## Mostrar.
plt.bar(x=x1, height=y1)
plt.show() # por defecto Jupyter muesta el gráfico, en otros entornos hay que colocar plt.show()

# %%
## Versión mejorada con barras horizontales
## pueden consultar esta referencia - https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
## colores - https://matplotlib.org/stable/gallery/color/named_colors.html

## grafico.
plt.figure(figsize=(14,10))
plt.grid( color ='grey',linestyle ='-.', linewidth = 0.5, alpha = 0.9)
plt.title( "GOLES A FAVOR X PAIS", color='blue')
plt.xlabel( "GOLES A FAVOR", color='blue')
plt.ylabel( "PAISES", color='blue')
plt.xticks(rotation='vertical')

## puede ser horizontal
plt.axvline( y1.mean(), color='tomato',lw=2, linestyle='--' )
plt.barh(y=x1, width=y1, color='palegreen')

## guarda el gráfico en la ruta selecionada.
#plt.savefig('guardar/a_worldcup_barra.jpg') # pdf, png, otros

## muestra el gráfico.
plt.show()

# %%
## puede ser vertical, pero no se ve bien el texto de abajo
plt.axhline( y1.mean(), color='RED',lw=6, linestyle='--' )
plt.bar(x=x1, height=y1, color='green')
# Out:
# <BarContainer object of 32 artists>

# %% [markdown]
# ## E- Graficando algunas variables: Scatterplot y Torta.
#
# * En este scaterplot graficaremos una variable o serie.
# * Usted puede probar agregando títulos, cambiando colores, tamaños, guardando el gráfico, etc.
# * Marcadores de puntos - https://matplotlib.org/stable/api/markers_api.html

# %%
## Scatterplot de una serie.

## Variables.
x1 = df['team'] # en x1 la variable dependiente
y1 = df['goles_favor'] # en y1 guardaremos la variable dependiente

#plt.figure(figsize=(14,10))
plt.scatter(x=x1, y=y1, color='red') # gráfico de puntos.

# %%
## Scatterplot de dos series
## En este scatterplot graficaremos dos variables o series.

## Datos - guardar datos en dos variables
d1 = (df['team'], df['goles_favor'])
d2 = (df['team'], df['goles_contra'])

sdatos = (d1, d2) # guardamos esos grupos en la variable datos.
snombres = ('Goles a favor', 'Goles en contra') # guardamos esos grupos en la variable datos.
scolores = ('red', 'dodgerblue') #


### Crear grafico - - - - - - - - - - - -
fig=plt.figure(figsize=(18, 10) ) # tamaño del gráfico.
fig.patch.set_facecolor('green') # color del margen.
fig.patch.set_alpha(0.9) # transparencia del margen.

ax = fig.add_subplot(1, 1, 1) # sub gráficos en el mismo espacio.
ax.patch.set_color('fuchsia') # transparencia del gráfico.
ax.patch.set_alpha(0.9) # transparencia del gráfico.


## Titulos y colores - - - - - - - - - - - -
plt.title("Relación Goles Favor - Goles Contra'") # título.
plt.xticks(rotation=0)
plt.xlabel("Equipos") # texto eje X.
plt.ylabel("Goles") # texto eje Y.
plt.grid( color='blue', alpha=0.9) # grilla.

## Ciclo recorre sdatos, scolores, snombres y se guardan en dat, col, gru.
for dat, col, gru in zip(sdatos, scolores, snombres):
    x, y = dat
    ax.scatter(x, y, alpha=0.6, c=col, edgecolors='none', s=180, label=gru, marker='D') # puntos.
    plt.legend(snombres) # leyendas


## Mostrar y guardar gráfico - - - - - - - - - - - -
# guarda el gráfico en la ruta seleccionada.
#plt.savefig('guardar/c_cuarteto_scatter_series.jpg')
# esta linea muestra el gráfico.
plt.show()

# %%
## Gráfico de torta, gráfica de distribución de valores.
## Nadie los quiere los gráficos de torta, así que recordémoslo con cariño.

## Datos
continentes   = ['europe','southamerica','africa','northamerica','asia']
cuantospaises = [13, 6, 5, 4, 4]

## hacer la torta
fig = plt.figure(figsize =(8, 8))
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(cuantospaises, labels = continentes)
plt.show()

# %% [markdown]
# ## - - - - - - - - Ahora Usted! - - - - - - - - - - - - -
#
# REPLICAR PROCESO
#
# Replique todos los siguientes pasos del 1 al 6, pero con otros datos.
#
#     0- Importar librerias.
#     1- Cargar Datos y Exploracion inicial.
#     2- Medidas de tendencia central o posición.
#     3- Medidas de dispersión, variación o variabilidad.
#     4- Graficando algunas variables: Barras.
#     5- Graficando algunas variables: Scatterplot y Torta.
#     6- Mejorar Gráfica.
#
# En la carpeta datos_e10 se podrán encontrar varios datasets que pueden usar. Puede escoger cualquiera (menos worldcup2014.csv) y escoger las variables recomendadas (en paréntesis). Todos los archivos están en formato csv.
#
#     wimbledon.csv
#     titanic3_corto.csv: sep=";", variables sugeridas (age, fare)
#     terremotos_all_month.csv: sep="", variables sugeridas (depth, mag, dmin)
#     obesidad_adultos_2000_2016.csv: sep=",", variables sugeridas (cualquier año)
#     goleadores_mundiales.csv: sep=";", variables sugeridas (Goles, P. J., Prom.)
#     datos_comunas_chile.csv: sep=",", variables sugeridas (Superficie, Población, Densidad, IDH2005)
#
# Recuerde que al comenzar se deben importar las librerías correspondientes que están al inicio del archivo. Puede crear las celdas que necesite.
# Recordar además que puede mirar los archivos con un editor de texto simple e identificar cuál es el separador entre los datos: puede ser coma (,), punto y coma (;), u otro.

# %% [markdown]
# ## 0- Importar librerias (0 punto).

# %%
## Su respuestas desde acá...

# %% [markdown]
# ## 1- Cargar Datos y Exploracion inicial (0 punto).

# %%
## Su respuestas desde acá...

df2 = pd.read_csv('?', sep=',') # ojo el separador

## Mostrar datos
df2

# %%
## Su respuestas desde acá...
## explorar los datos con shape, info, column, head, tail, etc.

## Columnas
print(df2.columns)

# %% [markdown]
# ## 2- Medidas de tendencia central o posición (0 punto).

# %%
## Su respuestas desde acá...
## Puede usar mean, median o mode

# %% [markdown]
# ## 3- Medidas de dispersión, variación o variabilidad (0 punto).

# %%
## Su respuestas desde acá...
## Explorar max, min, sdt...

# %% [markdown]
# ## 4- Graficando algunas variables: Barras (1 punto).

# %%
## Su respuestas desde acá...
## Gráfico de barras de una columna.

# %%
## Versión mejorada con barras horizontales

# %% [markdown]
# ## 5- Graficando algunas variables: Scatterplot y Torta (0 punto).

# %%
## Su respuestas desde acá...
## Scatterplot una serie.

# %%
## Scatterplot de dos series
## Graficaremos dos variables o series.
## El gráfico está horrible, puede ajustar los colores y otros parámetros.

# %%
## Gráfico de torta.
## Seleccionar una variable numérica y otra no numérica (usar info() para averiguar tipo de dato)

# %% [markdown]
# ## 6- Mejorar Gráfica (0 punto).
#
# El Scatterplot de dos series está horrible. Puede tomar el mismo código de E y mejorarlo: ajustar los colores y otros parámetros.
#
# Algunas referencias de ayuda:
#
# – Colores: https://matplotlib.org/stable/gallery/color/named_colors.html
# – Cheatsheets Matplotlib : https://matplotlib.org/cheatsheets/
#
# Incluso puede usar otra librería como seaborn.
# – Web Seaborn: https://seaborn.pydata.org/
#
# Acá un código de inicio para seaborn:
#
# import seaborn as sns
# sns.scatterplot(x = "x", y = "y", data = df)

# %%
## Su respuestas desde acá...
